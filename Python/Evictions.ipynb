# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdate
import numpy as np

# %%
ri_data = pd.read_csv('~/Downloads/rhode_island_barchart (1).csv')
print(ri_data)
ri_data['month'] = pd.to_datetime(ri_data['month'])
print(ri_data)
ri_data = ri_data.sort_values(by = 'month')
# Out:
#       month  month_last_day  month_filings  avg_filings  percentage_diff
# 0   01/2020             NaN            823        823.0         1.000000
# 1   01/2021             NaN            404        823.0         0.490887
# 2   01/2022             NaN            509        823.0         0.618469
# 3   01/2023             NaN            853        823.0         1.036452
# 4   01/2024             NaN            795        823.0         0.965978
# ..      ...             ...            ...          ...              ...
# 60  12/2020             NaN            423        502.5         0.841791
# 61  12/2021             NaN            483        502.5         0.961194
# 62  12/2022             NaN            656        502.5         1.305473
# 63  12/2023             NaN            537        502.5         1.068657
# 64  12/2024             NaN            469        502.5         0.933333
#
# [65 rows x 5 columns]
# ...

# %%
plt.plot(ri_data['month'], ri_data['month_filings'])
print(ri_data)
plt.title("Rhode Island Data")
plt.xlabel('month')
plt.ylabel('month filing')
# Out:
#         month  month_last_day  month_filings  avg_filings  percentage_diff
# 0  2020-01-01             NaN            823        823.0         1.000000
# 6  2020-02-01             NaN            577        592.5         0.973840
# 12 2020-03-01             NaN            273        700.5         0.389722
# 18 2020-04-01             NaN              1        574.0         0.001742
# 24 2020-05-01             NaN              1        694.5         0.001440
# ..        ...             ...            ...          ...              ...
# 5  2025-01-01             NaN            538        823.0         0.653706
# 11 2025-02-01             NaN            416        575.5         0.722850
# 17 2025-03-01             NaN            492        700.5         0.702355
# 23 2025-04-01             NaN            477        574.0         0.831010
# 29 2025-05-01             NaN            480        694.5         0.691145
#
# [65 rows x 5 columns]
# Text(0, 0.5, 'month filing')
