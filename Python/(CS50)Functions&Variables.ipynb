# %% [markdown]
# CS50's Function and Varaibles
# =============================

# %%
print("hello, world")
print("Whats your name? ")
input()
# Out:
# hello, world
# Whats your name?
#  Belle
# 'Belle'

# %%
#ask user their name
name = input("Whats your name? ")

#say hello to user
print("hello,")
print(name)
# Out:
# Whats your name?  Belle
# hello,
# Belle

# %%
# ask user for their name
name = input("Whats your name? ")

# say hello to user
print("hello, " + name)
# Out:
# Whats your name?  Belle
# hello, Belle

# %%
# ask user for their name
name = input("Whats your name? ")

#remove whitespace from str(string) and capatalize
name = name.strip().title()

# say hello to user
print(f"hello, {name}")
# Out:
# Whats your name?      belle  d
# hello, Belle  D

# %%
# ask user for their name
name = input("Whats your name? ").strip().title()

#Split user's name into first and last
first, last = name.split(" ")

# say hello to user
print(f"hello, {name}")
# Out:
# Whats your name?  belle dipasquale
# hello, Belle Dipasquale

# %%
"""
Integers (int) + - * / %
"""

x = input("What's x? ")
y = input("What's y? ")

z = int(x) + int(y)
print(z)
# Out:
# What's x?  4
# What's y?  12
# 16

# %%
"""
Integers (int) + - * / %
"""

x = int(input("What's x? "))
y = int(input("What's y? "))

z = x + y
print(z)
# Out:
# What's x?  4
# What's y?  12
# 16

# %%
objects = [1,2,3]
print(*objects, sep=' ', end='\n', file=sys.stdout, flush=False)
# Out:
# 1 2 3

# %%
def hello(to='world'):
    print("hello", to)

hello()
name = input("What's your name? ")
hello(name)
# Out:
# hello world
# What's your name?  belle
# hello belle
