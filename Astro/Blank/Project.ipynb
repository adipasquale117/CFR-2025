# %% [markdown]
# ### Project plot!
#
# Have your code for your project plot here. All data is in the ../Data/CFR_project_data folder

# %%
import pandas as pd
import numpy as np
import h5py
import matplotlib.pyplot as plt
import matplotlib

# %%
# Import spiral data
spiral_1 = pd.read_csv('../Data/CFR_project_data//belle/p_spiral_0.5.csv')
spiral_2 = pd.read_csv('../Data/CFR_project_data/belle/p_spiral_1.5.csv')
spiral_3 = pd.read_csv('../Data/CFR_project_data/belle/p_spiral_1.csv')
spiral_4 = pd.read_csv('../Data/CFR_project_data//belle/p_spiral_2.5.csv')
spiral_5 = pd.read_csv('../Data/CFR_project_data/belle/p_spiral_2.csv')
spiral_6 = pd.read_csv('../Data/CFR_project_data/belle/p_spiral_3.csv')

spiral_1
# Out:
#       Probability is spiral (decimal)
# 0                            0.332089
# 1                            0.729262
# 2                            0.512348
# 3                            0.801153
# 4                            0.510369
# ...                               ...
# 2918                         0.010956
# 2919                         0.680102
# 2920                         0.907103
# 2921                         0.577926
# 2922                         0.513414
#
# [2923 rows x 1 columns]

# %%
# spiral variables
spiral1 = spiral_1['Probability is spiral (decimal)']
spiral2 = spiral_2['Probability is spiral (decimal)']
spiral3 = spiral_3['Probability is spiral (decimal)']
spiral4 = spiral_4['Probability is spiral (decimal)']
spiral5 = spiral_5['Probability is spiral (decimal)']
spiral6 = spiral_6['Probability is spiral (decimal)']

z=[spiral1, spiral2, spiral3, spiral4, spiral5, spiral6]
# turn these probabilities into a spiral fraction for each redshift
#spiral = prob_spiral >= .8

# %%
spiral01 = np.mean(spiral1)
print(spiral01)

spiral02 = np.mean(spiral2)
print(spiral02)

spiral03 = np.mean(spiral3)
print(spiral03)

spiral04 = np.mean(spiral4)
print(spiral04)

spiral05 = np.mean(spiral5)
print(spiral05)

spiral06 = np.mean(spiral6)
print(spiral06)

spiral_bool = [spiral01, spiral02, spiral03, spiral04, spiral05, spiral06]
# Out:
# 0.712830536392063
# 0.6023063791692651
# 0.6775142292271624
# 0.3739196782963103
# 0.46554054504978387
# 0.2776216822808028

# %%
plt.scatter(y=spiral01, x = 'Spiral Fraction')
plt.scatter(y=spiral02, x = 'Spiral Fraction')
plt.scatter(y=spiral03, x = 'Spiral Fraction')
plt.scatter(y=spiral04, x = 'Spiral Fraction')
plt.scatter(y=spiral05, x = 'Spiral Fraction')
plt.scatter(y=spiral06, x = 'Spiral Fraction')

# %%
plt.scatter(x = spiral_bool, y = 'spiral fraction')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 plt.scatter(x = spiral_bool, y = 'spiral fraction')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3903, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3884 @_copy_docstring_and_deprecators(Axes.scatter)
#    3885 def scatter(
#    3886     x: float | ArrayLike,
#    (...)
#    3901     **kwargs,
#    3902 ) -> PathCollection:
# -> 3903     __ret = gca().scatter(
#    3904         x,
#    3905         y,
#    3906         s=s,
#    3907         c=c,
#    3908         marker=marker,
#    3909         cmap=cmap,
#    3910         norm=norm,
#    3911         vmin=vmin,
#    3912         vmax=vmax,
#    3913         alpha=alpha,
#    3914         linewidths=linewidths,
#    3915         edgecolors=edgecolors,
#    3916         plotnonfinite=plotnonfinite,
#    3917         **({"data": data} if data is not None else {}),
#    3918         **kwargs,
#    3919     )
#    3920     sci(__ret)
#    3921     return __ret
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:4787, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4785 y = np.ma.ravel(y)
#    4786 if x.size != y.size:
# -> 4787     raise ValueError("x and y must be the same size")
#    4789 if s is None:
#    4790     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4791          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size

# %%
x = np.array[67, 50, 40, 33, 29, 25]
y = np.array[.5, 1, 1.5, 2, 2.5, 3]

plt.scatter(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 x = np.array[67, 50, 40, 33, 29, 25]
#       2 y = np.array[.5, 1, 1.5, 2, 2.5, 3]
#       4 plt.scatter(x,y)
#
# TypeError: 'builtin_function_or_method' object is not subscriptable
